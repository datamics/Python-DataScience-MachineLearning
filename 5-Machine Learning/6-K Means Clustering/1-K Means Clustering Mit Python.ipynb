# %% [markdown]
# <a href="https://datamics.com/de/courses/"><img src=../../DATA/bg_datamics_top.png></a>
#
# <em text-align:center>© Datamics</em>
# # K Means Clustering mit Python
#
# Dieses Noteboo dient als Code Referenz zu den Erklärungen in der Video-Lektion.
#
# ## Angewendete Methode
#
# K Means Clustering ist ein Unsupervised Learning Algoithmus. Dieser versucht Daten aufgrund ihrer Ähnlichkeit in Cluster einzuteilen. Unsupervised Lerning bedeutet, dass wir vorab keine Zuordnung kennen und versuchen Muster in den Daten zu erkennen, die eine Zuordnung rechtertigen.
#
# Beim K Means Clustering definieren wir die Anzahl an Clustern, in die wir die Daten aufteilen möchten. Der Algorithmus teilt jede Beobachtung zufällig einem Cluster zu. Danach findet es den Mittelpunkt jedes Clusters. Anschließend folgt der Algorithmus den folgenden zwei Schritten:
#
# 1. Weise die Beobachtungen dem Cluster-Mittepunkt zu, der ihnen am nächsten ist.
# 2. Berechne neue Mittelpunkte für die angepassten Clusters.
#
# Diese beiden Schritte werden solange wiederholt, bis die "within-cluster-variation" nicht mehr veringert werden kann. Diese wird durch die Summe der euklidische Distanz eines jeden Punktes zum Mittelpunkt seines Clusters berechnet.
#
# ## Libraries importieren

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Einige Daten erzeugen

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=200, n_features=2, 
                           centers=4, cluster_std=1.8,random_state=101)

# %% [markdown]
# # Daten Visualisieren

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %% [markdown]
# ## Cluster erzeugen

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=4)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[-4.13591321,  7.95389851],
#        [-9.46941837, -6.56081545],
#        [ 3.71749226,  7.01388735],
#        [-0.0123077 ,  2.13407664]])

# %%
kmeans.labels_
# Out:
# array([0, 2, 3, 2, 2, 1, 2, 3, 2, 3, 0, 3, 2, 2, 0, 3, 2, 3, 1, 0, 1, 3,
#        3, 1, 0, 1, 1, 3, 2, 2, 0, 1, 2, 3, 3, 0, 1, 1, 1, 3, 1, 0, 0, 0,
#        3, 2, 0, 3, 1, 3, 3, 0, 2, 3, 1, 0, 3, 3, 0, 2, 1, 2, 1, 0, 2, 3,
#        1, 2, 2, 1, 2, 3, 1, 3, 1, 2, 2, 3, 0, 3, 3, 1, 2, 1, 3, 3, 3, 0,
#        3, 1, 1, 1, 1, 3, 3, 1, 2, 0, 1, 2, 3, 1, 3, 3, 2, 3, 1, 2, 1, 1,
#        2, 0, 0, 2, 1, 2, 0, 0, 2, 0, 3, 0, 3, 0, 3, 2, 0, 3, 1, 0, 0, 0,
#        3, 1, 1, 0, 2, 0, 2, 3, 1, 2, 1, 0, 0, 2, 3, 1, 0, 0, 0, 0, 3, 2,
#        3, 0, 2, 2, 2, 3, 2, 3, 3, 0, 1, 0, 3, 2, 0, 3, 2, 3, 0, 2, 3, 0,
#        2, 2, 1, 2, 0, 1, 1, 0, 1, 1, 1, 1, 1, 3, 1, 2, 2, 0, 1, 3, 2, 2,
#        1, 3])

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')
ax2.set_title("Original")
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %% [markdown]
# *Hinweis: Die Farbunterschiede zwischen den beiden Polts spielen hier keine Rolle. Nur die Punktzugehörigkeit zu einer Farbe.*
#
# # Gut gemacht!
